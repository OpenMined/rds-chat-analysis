# %% [markdown]
# # TODO
# - setup LLM, embedder, DB keys for mock and private and store in .env.mock + .env.private
# - Setup syftbox, login, connect to RDS
# - ...

# %%
from langchain.chat_models import init_chat_model
import dotenv
from rds_chat_analysis import NOTEBOOK_DIR
import os

dotenv.load_dotenv(f"{NOTEBOOK_DIR}/.env.mock")

llm = init_chat_model(
    model=os.environ["OPENROUTER_MODEL_NAME"],
    model_provider=os.environ["MODEL_PROVIDER"],
    openai_api_key=os.environ["OPENROUTER_API_KEY"],
    openai_api_base=os.environ["OPENROUTER_API_URL"],
)
